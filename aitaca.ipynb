# %% [markdown]
# ## REPOSITORY FOR AITACA
#
# Claudia Pérez Sánchez
# 22/03/2022

# %%
import argparse
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


def main():
    """
    Step 1.
    Create an array of 10 rows and 2 columns with random integers between 0 and 10 inclusive.
    Store it in the variable "b". Concatenate variables a and b so that the result is an array of 10 rows and 3 columns.
    Store the result in the variable "c" and display it on the screen.
    """
    
    print("STEP 1")
    b = np.random.randint(11, size=(10,2))
    a = np.random.randint(11, size=(10,1))
    c = np.column_stack((b, a))
    print("matrix b is:\n ", b)
    print("matrix a is :\n", a)
    print("matrix c is:\n ", c)
    
    """
    Step 2.
    Using the np.where function, replace all values of c less than 10 with zeros.
    Using a universal function, it lifts each element of the obtained array.
    Display the results on the screen.
    """
    
    print("\nSTEP 2")
    d=np.where(c<10,0,c)
    print("matrix c replaced is:\n ", d)
    
    """
    Step 3.
    Develop a function that reads "Titanic" dataset given in the assessment and count the number of rows.
    Display the results on the screen
    (Optional) Make sure that it could be any format file (zip, pickle,...)
    """
    
    print("\nSTEP 3")
    titanic = pd.read_csv('titanic.txt', sep=',',header=None)
    print("number of rows from dataset: ", titanic.shape[0])
    
    """
    Step 4
    Using the *reindex* method, keep the "survived", "class", "sex", "age", "fare" and "embark_town" fields from the Titanic dataset.
    Add this into one function that returns the resulting dataframe.
    """
    
    print("\nSTEP 4")
    cols_to_keep = [1, 2, 4, 5, 9, 11]
    titanic_reindex = titanic.reindex(columns=cols_to_keep)
    print(titanic_reindex)
    
    """
    Step 5
    Install the Seaborn library using the command: pip install seaborn.
    Loads in the tips variable the DataFrame tips provided by the Seaborn library.
    Using only matplotlib functions, create a figure of size (8, 6) and display in it a scatter plot crossing the "tip" 
    and "total_bill" columns of the tips dataset.
    """
    
    print("\nSTEP 5")
    tips = sns.load_dataset("tips")
    print(tips)
    fig, ax = plt.subplots(figsize=(8,6))
    ax.scatter(tips['total_bill'], tips['tip'], color='r')
    ax.set_xlabel('Total Bill')
    ax.set_ylabel('Tips')
    ax.set_title('scatter plot')
    plt.show()


if __name__ == "__main__":
    main()
# Out:
# STEP 1
# matrix b is:
#   [[ 7  5]
#  [10  5]
#  [ 5  8]
#  [10  8]
#  [ 4  6]
#  [ 7  9]
#  [ 4  1]
#  [ 6  0]
#  [ 4  9]
#  [ 1  4]]
# matrix a is :
#  [[ 1]
#  [ 7]
#  [ 7]
#  [ 6]
#  [ 6]
#  [10]
#  [ 8]
#  [ 1]
#  [10]
#  [10]]
# matrix c is:
#   [[ 7  5  1]
#  [10  5  7]
#  [ 5  8  7]
#  [10  8  6]
#  [ 4  6  6]
#  [ 7  9 10]
#  [ 4  1  8]
#  [ 6  0  1]
#  [ 4  9 10]
#  [ 1  4 10]]
#
# STEP 2
# matrix c replaced is:
#   [[ 0  0  0]
#  [10  0  0]
#  [ 0  0  0]
#  [10  0  0]
#  [ 0  0  0]
#  [ 0  0 10]
#  [ 0  0  0]
#  [ 0  0  0]
#  [ 0  0 10]
#  [ 0  0 10]]
#
# STEP 3
# number of rows from dataset:  892
#
# STEP 4
#            1       2       4    5        9         11
# 0    Survived  Pclass     Sex  Age     Fare  Embarked
# 1           0       3    male   22     7.25         S
# 2           1       1  female   38  71.2833         C
# 3           1       3  female   26    7.925         S
# 4           1       1  female   35     53.1         S
# ..        ...     ...     ...  ...      ...       ...
# 887         0       2    male   27       13         S
# 888         1       1  female   19       30         S
# 889         0       3  female  NaN    23.45         S
# 890         1       1    male   26       30         C
# 891         0       3    male   32     7.75         Q
#
# [892 rows x 6 columns]
#
# STEP 5
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Questions
#
# How long did you spend writing the application?
#
#     I sepnt like 3-4 hours more or less.
# What part of the application are you most proud of?
#
#     I am most proud of the steps 3 and 4 as I am not so used to work with datasets, this is the first year that i studied it.
# If you had more time what would you improve in the application?
#
#     I would improve the scatter plot to make it a little bit more visual and clear.
